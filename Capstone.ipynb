# %%
import pandas as pd
url="employee_attrition_data.csv"
df=pd.read_csv(url)
df.head()
# Out:
#    Employee_ID  Age  Gender   Department Job_Title  Years_at_Company  \
# 0            0   27    Male    Marketing   Manager                 9
# 1            1   53  Female        Sales  Engineer                10
# 2            2   59  Female    Marketing   Analyst                 8
# 3            3   42  Female  Engineering   Manager                 1
# 4            4   44  Female        Sales  Engineer                10
#
#    Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0            0.586251                    151                      0   60132
# 1            0.261161                    221                      1   79947
# 2            0.304382                    184                      0   46958
# 3            0.480779                    242                      0   40662
# 4            0.636244                    229                      1   74307
#
#    Attrition
# 0          0
# 1          0
# 2          1
# 3          0
# 4          0

# %%
print(df)
# Out:
#      Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 0              0   27    Male    Marketing        Manager                 9
# 1              1   53  Female        Sales       Engineer                10
# 2              2   59  Female    Marketing        Analyst                 8
# 3              3   42  Female  Engineering        Manager                 1
# 4              4   44  Female        Sales       Engineer                10
# ..           ...  ...     ...          ...            ...               ...
# 995          995   39  Female           HR  HR Specialist                 3
# 996          996   50    Male  Engineering        Manager                 1
# 997          997   52    Male  Engineering        Analyst                 3
# 998          998   37  Female           HR  HR Specialist                 2
# 999          999   59    Male        Sales  HR Specialist                 1
#
#      Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0              0.586251                    151                      0   60132
# 1              0.261161                    221                      1   79947
# 2              0.304382                    184                      0   46958
# 3              0.480779                    242                      0   40662
# 4              0.636244                    229                      1   74307
# ..                  ...                    ...                    ...     ...
# 995            0.377435                    239                      0   71403
# 996            0.431152                    154                      0   30181
# 997            0.647102                    206                      0   64143
# 998            0.304813                    241                      0   74383
# 999            0.940510                    159                      0   73220
#
#      Attrition
# 0            0
# 1            0
# 2            1
# 3            0
# 4            0
# ..         ...
# 995          0
# 996          1
# 997          0
# 998          1
# 999          1
#
# [1000 rows x 11 columns]

# %%
df.head(10)
# Out:
#    Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 0            0   27    Male    Marketing        Manager                 9
# 1            1   53  Female        Sales       Engineer                10
# 2            2   59  Female    Marketing        Analyst                 8
# 3            3   42  Female  Engineering        Manager                 1
# 4            4   44  Female        Sales       Engineer                10
# 5            5   47    Male        Sales  HR Specialist                10
# 6            6   58    Male    Marketing  HR Specialist                 5
# 7            7   57  Female        Sales        Analyst                 8
# 8            8   34  Female      Finance     Accountant                 6
# 9            9   57  Female    Marketing       Engineer                 7
#
#    Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0            0.586251                    151                      0   60132
# 1            0.261161                    221                      1   79947
# 2            0.304382                    184                      0   46958
# 3            0.480779                    242                      0   40662
# 4            0.636244                    229                      1   74307
# 5            0.889018                    237                      0   97212
# 6            0.688977                    155                      1   97865
# 7            0.981679                    171                      0   50113
# 8            0.010381                    177                      1   88747
# 9            0.466782                    170                      0   43283
#
#    Attrition
# 0          0
# 1          0
# 2          1
# 3          0
# 4          0
# 5          0
# 6          0
# 7          0
# 8          1
# 9          0

# %%
df.tail(10)
# Out:
#      Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 990          990   36  Female  Engineering     Accountant                 9
# 991          991   47    Male    Marketing        Manager                 2
# 992          992   46  Female           HR        Analyst                 8
# 993          993   47  Female           HR        Analyst                 5
# 994          994   47    Male    Marketing  HR Specialist                 2
# 995          995   39  Female           HR  HR Specialist                 3
# 996          996   50    Male  Engineering        Manager                 1
# 997          997   52    Male  Engineering        Analyst                 3
# 998          998   37  Female           HR  HR Specialist                 2
# 999          999   59    Male        Sales  HR Specialist                 1
#
#      Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 990            0.558512                    182                      1   65638
# 991            0.889621                    243                      0   78726
# 992            0.955095                    176                      1   79044
# 993            0.932450                    193                      0   47301
# 994            0.992018                    186                      1   31507
# 995            0.377435                    239                      0   71403
# 996            0.431152                    154                      0   30181
# 997            0.647102                    206                      0   64143
# 998            0.304813                    241                      0   74383
# 999            0.940510                    159                      0   73220
#
#      Attrition
# 990          1
# 991          1
# 992          1
# 993          0
# 994          0
# 995          0
# 996          1
# 997          0
# 998          1
# 999          1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee_ID            1000 non-null   int64
#  1   Age                    1000 non-null   int64
#  2   Gender                 1000 non-null   object
#  3   Department             1000 non-null   object
#  4   Job_Title              1000 non-null   object
#  5   Years_at_Company       1000 non-null   int64
#  6   Satisfaction_Level     1000 non-null   float64
#  7   Average_Monthly_Hours  1000 non-null   int64
#  8   Promotion_Last_5Years  1000 non-null   int64
#  9   Salary                 1000 non-null   int64
#  10  Attrition              1000 non-null   int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 86.1+ KB

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Department', 'Job_Title',
#        'Years_at_Company', 'Satisfaction_Level', 'Average_Monthly_Hours',
#        'Promotion_Last_5Years', 'Salary', 'Attrition'],
#       dtype='object')

# %%
df.isna()
# Out:
#      Employee_ID    Age  Gender  Department  Job_Title  Years_at_Company  \
# 0          False  False   False       False      False             False
# 1          False  False   False       False      False             False
# 2          False  False   False       False      False             False
# 3          False  False   False       False      False             False
# 4          False  False   False       False      False             False
# ..           ...    ...     ...         ...        ...               ...
# 995        False  False   False       False      False             False
# 996        False  False   False       False      False             False
# 997        False  False   False       False      False             False
# 998        False  False   False       False      False             False
# 999        False  False   False       False      False             False
#
#      Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0                 False                  False                  False   False
# 1                 False                  False                  False   False
# 2                 False                  False                  False   False
# 3                 False                  False                  False   False
# 4                 False                  False                  False   False
# ..                  ...                    ...                    ...     ...
# 995               False                  False                  False   False
# 996               False                  False                  False   False
# 997               False                  False                  False   False
# 998               False                  False                  False   False
# 999               False                  False                  False   False
#
#      Attrition
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ..         ...
# 995      False
# 996      False
# 997      False
# 998      False
# 999      False
#
# [1000 rows x 11 columns]

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.drop(columns="Employee_ID",inplace=True)

# %%
df.head()
# Out:
#    Age  Gender   Department Job_Title  Years_at_Company  Satisfaction_Level  \
# 0   27    Male    Marketing   Manager                 9            0.586251
# 1   53  Female        Sales  Engineer                10            0.261161
# 2   59  Female    Marketing   Analyst                 8            0.304382
# 3   42  Female  Engineering   Manager                 1            0.480779
# 4   44  Female        Sales  Engineer                10            0.636244
#
#    Average_Monthly_Hours  Promotion_Last_5Years  Salary  Attrition
# 0                    151                      0   60132          0
# 1                    221                      1   79947          0
# 2                    184                      0   46958          1
# 3                    242                      0   40662          0
# 4                    229                      1   74307          0

# %%
import matplotlib.pyplot as plt
df["Gender"].value_counts().plot(kind="pie")
plt.ylabel("")
plt.title("Gender count of Employees")
plt.show()

# %%
df.groupby("Job_Title")["Salary"].mean().sort_values(ascending=False).plot(kind="line")
plt.xlabel("Job Title")
plt.ylabel("Salary")
plt.title("Average Salary by Job Title")
plt.show()

# %%
df.groupby(["Department","Promotion_Last_5Years"])["Salary"].mean().reset_index()
# Out:
#     Department  Promotion_Last_5Years        Salary
# 0  Engineering                      0  65541.063636
# 1  Engineering                      1  62424.127660
# 2      Finance                      0  63390.145299
# 3      Finance                      1  62041.269663
# 4           HR                      0  63012.556701
# 5           HR                      1  65882.861702
# 6    Marketing                      0  65251.597826
# 7    Marketing                      1  66018.632653
# 8        Sales                      0  64295.846939
# 9        Sales                      1  67838.756757

# %%
df.head()
# Out:
#    Age  Gender   Department Job_Title  Years_at_Company  Satisfaction_Level  \
# 0   27    Male    Marketing   Manager                 9            0.586251
# 1   53  Female        Sales  Engineer                10            0.261161
# 2   59  Female    Marketing   Analyst                 8            0.304382
# 3   42  Female  Engineering   Manager                 1            0.480779
# 4   44  Female        Sales  Engineer                10            0.636244
#
#    Average_Monthly_Hours  Promotion_Last_5Years  Salary  Attrition
# 0                    151                      0   60132          0
# 1                    221                      1   79947          0
# 2                    184                      0   46958          1
# 3                    242                      0   40662          0
# 4                    229                      1   74307          0

# %%
X = df[["Years_at_Company","Satisfaction_Level","Average_Monthly_Hours"]]
y = df["Salary"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X
# Out:
#      Years_at_Company  Satisfaction_Level  Average_Monthly_Hours
# 0                   9            0.586251                    151
# 1                  10            0.261161                    221
# 2                   8            0.304382                    184
# 3                   1            0.480779                    242
# 4                  10            0.636244                    229
# ..                ...                 ...                    ...
# 995                 3            0.377435                    239
# 996                 1            0.431152                    154
# 997                 3            0.647102                    206
# 998                 2            0.304813                    241
# 999                 1            0.940510                    159
#
# [1000 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.45720001, -1.48813806, -0.11007937],
#        [-1.6672531 ,  1.02963887,  0.65772214],
#        [ 1.51942657,  1.32009154,  1.25861028],
#        ...,
#        [-1.6672531 , -0.12528192, -0.44390611],
#        [ 1.16535105,  0.52838538, -0.74435018],
#        [-0.95910206,  1.35059926,  0.45742609]], shape=(800, 3))

# %%
import joblib
joblib.dump(scaler,"scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 0.45720001, -0.50640232, -0.34375809],
#        [-1.31317758,  0.50549734, -0.34375809],
#        [ 0.81127553, -0.59786762, -1.24509029],
#        [ 0.45720001,  0.77714991,  0.79125284],
#        [-1.6672531 ,  0.62268404, -1.64568238],
#        [-1.31317758, -1.62414765,  0.72448749],
#        [-0.25095102,  0.52367365,  0.85801819],
#        [ 1.51942657,  1.01622192,  1.19184493],
#        [-1.31317758, -0.43726159,  0.75787016],
#        [-0.60502654, -0.96985939,  0.25713005],
#        [-0.60502654,  0.82201355, -1.41200366],
#        [-1.6672531 ,  1.58184223,  0.95816621],
#        [ 1.51942657, -0.12580121, -0.34375809],
#        [ 0.45720001,  0.63874555, -0.04331402],
#        [-1.31317758, -0.77991769,  0.69110481],
#        [-1.31317758, -0.25747371,  0.52419144],
#        [-0.60502654,  0.30992295,  0.056834  ],
#        [-0.25095102, -0.01723022,  0.45742609],
#        [-1.31317758, -1.65945148,  0.75787016],
#        [ 1.51942657, -0.98701138, -0.61081948],
#        [-0.60502654,  0.9982326 , -1.04479425],
#        [-0.95910206,  1.37219156, -0.64420216],
#        [ 1.16535105,  0.78157422,  0.09021668],
#        [ 0.81127553,  1.01924844,  0.92478353],
#        [-0.25095102, -1.21692439, -1.1115596 ],
#        [ 1.51942657, -1.4929833 , -1.44538634],
#        [-0.95910206, -1.00391883, -1.34523832],
#        [ 1.16535105,  0.64619437,  0.056834  ],
#        [ 1.16535105,  1.18980272,  0.09021668],
#        [ 0.45720001,  0.61088122,  1.12507958],
#        [ 0.81127553, -0.84047402,  1.09169691],
#        [-0.60502654,  0.1381675 , -0.44390611],
#        [-1.6672531 , -0.69613512,  0.59095679],
#        [-0.25095102,  1.25537176, -1.04479425],
#        [ 0.10312449,  0.79813168,  1.12507958],
#        [-0.25095102, -1.1967564 , -1.47876901],
#        [ 1.16535105,  0.35244742, -1.57891704],
#        [-1.31317758, -0.78279199,  0.52419144],
#        [ 1.16535105,  0.44687631, -0.87788088],
#        [-1.6672531 ,  0.40073779,  0.55757412],
#        [ 1.16535105,  0.65570957, -1.01141157],
#        [ 0.10312449, -0.68252133, -1.44538634],
#        [ 0.45720001, -1.41579354,  1.62581969],
#        [-0.60502654, -0.41971703,  0.39066075],
#        [ 0.10312449,  0.88602251, -0.67758483],
#        [-1.31317758,  1.24417959, -1.57891704],
#        [-0.95910206, -0.39509201, -0.11007937],
#        [-0.95910206,  1.11819605, -1.07817692],
#        [-1.31317758,  1.00270674,  1.12507958],
#        [ 0.10312449,  0.65821408,  0.65772214],
#        [-0.95910206,  0.32322268,  0.85801819],
#        [-0.95910206,  0.36426933,  0.22374737],
#        [-0.25095102, -1.29494604,  1.29199295],
#        [ 0.10312449, -0.99113497, -0.14346204],
#        [ 0.10312449,  0.86511069,  1.02493156],
#        [ 0.81127553, -0.04689507, -0.34375809],
#        [-0.60502654, -1.35857625, -0.07669669],
#        [-0.95910206, -1.55111496,  1.65920237],
#        [ 0.45720001, -0.90834202, -1.54553436],
#        [-0.60502654,  0.54295057,  1.492289  ],
#        [-0.25095102, -0.73536002, -0.57743681],
#        [ 1.51942657, -1.33810536,  0.49080877],
#        [-0.25095102,  1.44455293,  0.99154888],
#        [-0.95910206, -0.54120414,  1.65920237],
#        [-1.6672531 ,  1.12559941,  0.02345133],
#        [-1.31317758,  0.41644081,  1.39214097],
#        [ 0.81127553, -0.68607541, -0.51067146],
#        [-0.60502654,  0.48462916, -0.31037541],
#        [-1.6672531 ,  0.33256748,  0.25713005],
#        [-0.95910206, -0.96249264, -0.11007937],
#        [-1.31317758,  1.54501021,  0.45742609],
#        [-0.25095102,  0.98139185, -1.44538634],
#        [ 0.45720001,  1.30237311,  0.65772214],
#        [ 0.81127553,  0.4104883 ,  1.25861028],
#        [-1.31317758, -0.12652452, -0.31037541],
#        [-0.60502654, -1.12800051, -0.77773285],
#        [ 0.45720001,  0.21839616,  0.09021668],
#        [-1.31317758,  1.32216102,  1.45890632],
#        [ 1.16535105,  0.53353785,  1.62581969],
#        [-1.31317758, -1.25814767, -0.24361007],
#        [ 0.45720001,  1.65193922, -1.17832494],
#        [-0.25095102, -1.15831025,  0.55757412],
#        [ 1.51942657, -0.82233595, -0.24361007],
#        [ 0.45720001,  1.29678215,  0.45742609],
#        [ 0.10312449, -1.7139279 ,  1.15846225],
#        [ 1.16535105, -0.10798068, -0.57743681],
#        [ 0.81127553,  0.78141108,  1.12507958],
#        [-0.60502654,  1.17872361, -1.04479425],
#        [ 0.10312449,  1.27967517, -0.57743681],
#        [ 1.51942657, -0.84762689, -0.54405413],
#        [ 0.45720001, -0.99737531,  1.65920237],
#        [-1.6672531 , -0.04886892,  1.25861028],
#        [-0.95910206,  1.17154698,  0.55757412],
#        [ 0.45720001, -1.65121701,  1.39214097],
#        [-0.60502654,  0.22470004, -1.54553436],
#        [-1.31317758, -1.01240776, -0.17684472],
#        [-0.60502654, -1.50475496, -0.8444982 ],
#        [ 1.16535105, -1.31175585,  0.49080877],
#        [ 0.10312449, -0.92606653,  1.25861028],
#        [-0.25095102, -1.27693257,  1.02493156],
#        [ 1.51942657, -0.23411997,  0.42404342],
#        [-1.31317758,  0.81611295,  0.39066075],
#        [ 0.10312449,  0.42449171,  0.29051272],
#        [-0.60502654, -0.67996753, -0.51067146],
#        [-1.6672531 , -1.70176213,  0.49080877],
#        [ 0.81127553,  0.91264696, -0.37714076],
#        [-0.60502654, -1.18957275,  0.45742609],
#        [-0.25095102,  1.00166682,  0.09021668],
#        [ 1.51942657, -0.51241423,  0.12359935],
#        [ 0.10312449,  0.94719944, -0.91126355],
#        [ 0.81127553, -0.59004356, -1.44538634],
#        [-1.31317758, -1.50226424,  1.12507958],
#        [ 0.81127553,  0.80468107,  1.39214097],
#        [ 0.10312449,  0.82717465, -1.61229971],
#        [-0.95910206, -0.05948197, -0.81111553],
#        [ 1.51942657, -1.10025811,  1.42552365],
#        [-1.31317758, -0.12225262,  1.52567167],
#        [ 0.81127553, -1.63273123,  1.05831423],
#        [ 0.10312449,  0.12222933, -1.14494227],
#        [ 0.81127553,  0.93729727, -0.31037541],
#        [ 1.51942657, -1.48165982,  1.19184493],
#        [-1.6672531 , -1.29817807, -0.91126355],
#        [-0.60502654,  1.63469354,  1.29199295],
#        [ 0.45720001, -0.55095269, -0.17684472],
#        [-1.6672531 ,  0.57842126,  0.29051272],
#        [ 0.81127553,  1.25746911, -0.8444982 ],
#        [-1.31317758, -1.15468788, -0.47728879],
#        [-1.6672531 ,  0.32043057, -1.54553436],
#        [-0.25095102,  1.44920391,  0.52419144],
#        [-1.6672531 ,  1.25052447,  0.55757412],
#        [-1.31317758, -1.38283402,  0.89140086],
#        [ 0.81127553,  1.56372213, -1.04479425],
#        [ 0.81127553, -0.51183154, -0.24361007],
#        [ 0.45720001,  0.41311278,  0.52419144],
#        [-0.60502654,  0.49524269,  0.39066075],
#        [ 0.10312449, -0.78502957,  1.2252276 ],
#        [-0.60502654,  0.67694842, -0.17684472],
#        [-0.95910206,  1.46441123, -0.14346204],
#        [ 0.10312449,  0.9153911 ,  0.39066075],
#        [-1.31317758, -0.51401232, -0.81111553],
#        [-0.60502654, -0.12610407, -0.81111553],
#        [ 1.51942657,  1.09854744, -1.54553436],
#        [ 1.16535105,  1.24299118, -0.71096751],
#        [-0.95910206,  0.62611993,  0.82463551],
#        [-1.6672531 , -0.62907974, -0.21022739],
#        [-0.95910206, -1.07942157, -0.44390611],
#        [ 1.51942657, -0.11216558, -1.21170762],
#        [-0.25095102,  0.07652344, -0.47728879],
#        [-1.6672531 , -0.51139134,  0.1903647 ],
#        [-1.6672531 ,  0.1820814 , -0.8444982 ],
#        [-0.25095102,  0.06507041, -1.51215169],
#        [ 0.45720001, -0.91486711, -1.27847297],
#        [-1.6672531 ,  0.86634114, -1.57891704],
#        [ 1.16535105,  1.26781716, -0.37714076],
#        [ 1.16535105,  0.20068182,  1.32537563],
#        [ 0.81127553,  0.44178374,  1.42552365],
#        [-0.25095102, -1.39641411,  0.35727807],
#        [ 0.45720001,  1.19515541, -1.57891704],
#        [ 0.10312449,  0.26147349,  1.42552365],
#        [-1.31317758,  1.10391575,  0.92478353],
#        [ 0.45720001,  0.37867476,  0.79125284],
#        [ 0.45720001, -0.15623953, -1.01141157],
#        [ 0.81127553, -0.5524249 ,  1.12507958],
#        [-0.25095102,  1.26223019,  0.09021668],
#        [-1.31317758, -0.39747099,  0.22374737],
#        [-0.95910206, -1.60393276,  0.89140086],
#        [ 0.45720001, -1.65904458,  1.59243702],
#        [ 0.45720001,  1.52142487,  1.45890632],
#        [-0.60502654,  1.00826313, -1.04479425],
#        [-0.25095102,  1.50998626,  1.52567167],
#        [-1.6672531 , -1.03016485,  0.62433947],
#        [-1.6672531 ,  0.10823461, -0.74435018],
#        [-1.6672531 ,  0.6194736 , -1.27847297],
#        [-0.95910206, -0.75676182,  0.89140086],
#        [ 0.10312449,  0.63401683, -1.01141157],
#        [-0.60502654,  1.23568494, -1.24509029],
#        [-0.25095102, -1.52513018,  0.99154888],
#        [ 1.51942657,  0.44034956,  0.09021668],
#        [-1.6672531 , -0.24930697, -0.71096751],
#        [ 1.16535105, -0.28198849, -1.14494227],
#        [ 1.16535105,  0.48041651,  0.12359935],
#        [ 1.16535105, -1.37219831,  1.15846225],
#        [ 0.10312449,  0.36486227,  0.02345133],
#        [-1.31317758, -0.00393685, -0.00993135],
#        [ 0.45720001, -1.34101648,  1.09169691],
#        [-0.95910206, -0.40120883,  0.59095679],
#        [ 0.45720001, -0.26607058, -0.44390611],
#        [-0.95910206,  0.96334468,  0.79125284],
#        [ 0.45720001, -0.42143665,  0.72448749],
#        [-0.60502654,  1.29776769, -0.27699274],
#        [-0.60502654,  1.59637882,  0.42404342],
#        [ 1.16535105, -1.62476576, -0.9780289 ],
#        [-0.25095102, -0.66484699, -0.14346204],
#        [-0.95910206,  0.70094274, -1.34523832],
#        [ 0.81127553,  0.56067333, -0.77773285],
#        [ 0.81127553,  1.05579645, -1.27847297],
#        [-1.31317758,  0.65797087, -1.17832494],
#        [-0.95910206,  1.58318262,  0.85801819],
#        [-0.60502654,  0.27457266, -1.21170762],
#        [ 0.45720001, -1.61610372, -0.00993135]])

# %%
import numpy as np
from sklearn.metrics import mean_squared_error,mean_absolute_error

def results(predictions):
  print("Mean absolute error on model is {}:",format(mean_absolute_error(y_test,predictions)))
  print("Root Mean squared error on model is {}:",format(np.sqrt(mean_squared_error(y_test,predictions))))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
pre = lr.predict(X_test)

# %%
results(pre)
# Out:
# Mean absolute error on model is {}: 16755.75935293025
# Root Mean squared error on model is {}: 19672.81842383392

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
svrmodel = SVR()
param_gridsvr={
    'C':[0.1,1,10],
    'epsilon':[0.1,0.2,0.5],
    'kernel':['linear','poly','rbf'],
    'degree':[2,3,4]
}
gridsvr = GridSearchCV(svrmodel,param_gridsvr)
gridsvr.fit(X_train,y_train.values.ravel())
# Out:
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.1, 1, 10], 'degree': [2, 3, 4],
#                          'epsilon': [0.1, 0.2, 0.5],
#                          'kernel': ['linear', 'poly', 'rbf']})

# %%
gridsvr.best_params_
# Out:
# {'C': 10, 'degree': 2, 'epsilon': 0.1, 'kernel': 'linear'}

# %%
prdictionssvr=gridsvr.predict(X_test)

# %%
results(prdictionssvr)
# Out:
# Mean absolute error on model is {}: 16748.09987891945
# Root Mean squared error on model is {}: 19641.22630530765

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
rfmodel = RandomForestRegressor()
param_gridrfr={
    'n_estimators':[2,3,4,5,6],
    'max_depth':[5,10,15]
}
gridrfr = GridSearchCV(rfmodel,param_gridrfr,cv=5)
gridrfr.fit(X_train,y_train.values.ravel())
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [5, 10, 15],
#                          'n_estimators': [2, 3, 4, 5, 6]})

# %%
gridrfr.best_params_
# Out:
# {'max_depth': 5, 'n_estimators': 6}

# %%
predictionofrfr=gridrfr.predict(X_test)

# %%
results(predictionofrfr)
# Out:
# Mean absolute error on model is {}: 16867.043925629776
# Root Mean squared error on model is {}: 19884.333722837375

# %%
lr
# Out:
# LinearRegression()

# %%
joblib.dump(lr,"model.pkl")
# Out:
# ['model.pkl']

# %%
X.columns
# Out:
# Index(['Years_at_Company', 'Satisfaction_Level', 'Average_Monthly_Hours'], dtype='object')

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, pre, label='Linear Regression Predictions', alpha=0.5)
plt.scatter(y_test, prdictionssvr, label='SVR GridSearchCV Predictions', alpha=0.5)
plt.scatter(y_test, predictionofrfr, label='Random Forest Predictions', alpha=0.5) # Added Random Forest predictions
plt.xlabel("Actual Salary")
plt.ylabel("Predicted Salary")
plt.title("Comparison of Linear Regression, SVR GridSearchCV, and Random Forest Predictions vs Actual Salary") # Updated title
plt.legend()
plt.grid(True)
plt.show()
